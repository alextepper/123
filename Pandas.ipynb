# %% [markdown]
# <a href="https://colab.research.google.com/github/alextepper/123/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('raw.githubusercontent.com_justmarkham_DAT8_master_data_chipotle.tsv', sep = '\t')
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.shape[0]
# Out:
# 4622

# %%
df.shape[1]
# Out:
# 5

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df['quantity'].sum()
# Out:
# 4972

# %%
df['choice_description'].value_counts()
# Out:
# [Diet Coke]                                                                                                                                      134
# [Coke]                                                                                                                                           123
# [Sprite]                                                                                                                                          77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                            42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                 40
#                                                                                                                                                 ...
# ...

# %%
df['item_price'] = df['item_price'].apply(lambda x: float(x[1:]))

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df['item_price'].sum()
# Out:
# 34500.16

# %%
df['order_id'].nunique()
# Out:
# 1834

# %%
df['item_price'].sum()/df['order_id'].nunique()
# Out:
# 18.811428571428575

# %%
df['choice_description'].nunique()
# Out:
# 1043

# %%
df[df['item_price']>10].shape[0]
# Out:
# 1130

# %%
users = pd.read_csv('raw.githubusercontent.com_justmarkham_DAT8_master_data_u.user.txt', sep = '|')
users.head(10)
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %%
users.groupby('occupation').mean('age')
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %%
cols = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]
iris = pd.read_csv('archive.ics.uci.edu_ml_machine-learning-databases_iris_iris.data.txt', sep=',', names = cols)
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
iris.isnull().values.any()
# Out:
# False

# %%
data = {
    'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
    'hp': [45, 39, 44, 45],
    'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
    'pokedex': ['yes', 'no', 'yes', 'no'],
    'type': ['grass', 'fire', 'water', 'bug']
}

# Convert dictionary into a DataFrame
pokemon = pd.DataFrame(data)
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %%
pokemon = pokemon[['name', 'type', 'hp', 'evolution', 'pokedex']]
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %%
baby_names = pd.read_csv('raw.githubusercontent.com_guipsamora_pandas_exercises_master_06_Stats_US_Baby_Names_US_Baby_Names_right.csv')
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name    Year Gender State  Count
# 0       11349  11350      Emma  2004.0      F    AK   62.0
# 1       11350  11351   Madison  2004.0      F    AK   48.0
# 2       11351  11352    Hannah  2004.0      F    AK   46.0
# 3       11352  11353     Grace  2004.0      F    AK   44.0
# 4       11353  11354     Emily  2004.0      F    AK   41.0
# 5       11354  11355   Abigail  2004.0      F    AK   37.0
# 6       11355  11356    Olivia  2004.0      F    AK   33.0
# 7       11356  11357  Isabella  2004.0      F    AK   30.0
# 8       11357  11358    Alyssa  2004.0      F    AK   29.0
# 9       11358  11359    Sophia  2004.0      F    AK   28.0

# %%
baby_names = baby_names.drop(['Unnamed: 0', 'Id'], axis = 1)
baby_names.head(10)
# Out:
#        Name    Year Gender State  Count
# 0      Emma  2004.0      F    AK   62.0
# 1   Madison  2004.0      F    AK   48.0
# 2    Hannah  2004.0      F    AK   46.0
# 3     Grace  2004.0      F    AK   44.0
# 4     Emily  2004.0      F    AK   41.0
# 5   Abigail  2004.0      F    AK   37.0
# 6    Olivia  2004.0      F    AK   33.0
# 7  Isabella  2004.0      F    AK   30.0
# 8    Alyssa  2004.0      F    AK   29.0
# 9    Sophia  2004.0      F    AK   28.0

# %%
investor_data = pd.read_csv('raw.githubusercontent.com_datasets_investor-flow-of-funds-us_master_data_weekly.csv')
investor_data.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2012-12-05         -7426            -6060         -1367     -74
# 1  2012-12-12         -8783            -7520         -1263     123
# 2  2012-12-19         -5496            -5470           -26     -73
# 3  2012-12-26         -4451            -4076          -375     550
# 4  2013-01-02        -11156            -9622         -1533    -158
#
#    Total Bond  Taxable Bond  Municipal Bond  Total
# 0        5317          4210            1107  -2183
# 1        1818          1598             219  -6842
# 2         103          3472           -3369  -5466
# 3        2610          3333            -722  -1291
# 4        2383          2103             280  -8931

# %%
investor_data.set_index('Date')
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-05         -7426            -6060         -1367     -74        5317
# 2012-12-12         -8783            -7520         -1263     123        1818
# 2012-12-19         -5496            -5470           -26     -73         103
# 2012-12-26         -4451            -4076          -375     550        2610
# 2013-01-02        -11156            -9622         -1533    -158        2383
# 2013-01-09         14817             7995          6821    2888        9766
# 2014-04-02          3155              938          2217     265        3379
# 2014-04-09          5761             2080          3681    1482        1609
# 2014-04-16          2286              634          1652    1186         633
# 2014-04-23          3530             1392          2138    1239        1984
# 2014-04-30         -3890            -3996           106     759         888
# ...
